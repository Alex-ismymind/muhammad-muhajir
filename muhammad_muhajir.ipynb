# %%
import re
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix
from nltk.tokenize import word_tokenize
from keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.models import Model
from keras.layers import Input, Dense, LSTM, Dropout, concatenate, Embedding
from tensorflow.keras.layers import Embedding
from keras.utils import plot_model
nltk.download('punkt_tab')

df = pd.read_csv('all_agree.csv')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
print(df['label_score'].value_counts())
# Out:
# label_score
# 0    5297
# 1    3316
# Name: count, dtype: int64

# %%
def find_punc(x, punc):
    count = 0
    for char in x:
        if char == punc :
            count += 1
    return count
def find_uppercase(x):
    count = 0
    for char in x:
        if char.isupper():
            count += 1
    return count
def find_lowercase(x):
    count = 0
    for char in x:
        if char.islower():
            count += 1
    return count
def find_number(x):
    import re
    return len(re.findall('[0-9]', x))

# %%
df['comma_count'] = df['title'].apply(lambda x: find_punc(x, ','))
df['stop_count'] = df['title'].apply(lambda x: find_punc(x, '.'))
df['question_count'] = df['title'].apply(lambda x: find_punc(x, '?'))
df['exclamation_count'] = df['title'].apply(lambda x: find_punc(x, '!'))
df['apostrophe_count'] = df['title'].apply(lambda x: find_punc(x, "'"))
df['colon_count'] = df['title'].apply(lambda x: find_punc(x, ':'))
df['semicolon_count'] = df['title'].apply(lambda x: find_punc(x, ';'))
df['uppercase_count'] = df['title'].apply(lambda x: find_uppercase(x))
df['lowercase_count'] = df['title'].apply(lambda x: find_lowercase(x))
df['number_count'] = df['title'].apply(lambda x: find_number(x))

# %%
print(df.shape)
# Out:
# (8613, 13)

# %%
def clean(text):
    text = text.lower()
    text = re.sub(r'[!.,?;:"]', '', text)
    word_tokens = word_tokenize(text)
    text = ' '.join(word_tokens)
    return text

# %%
df['cleaned_title'] = df['title'].apply(clean)

# %%
df[['title','cleaned_title']]
# Out:
#                                                   title  \
# 0     Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...
# 1     Malaysia Sudutkan RI: Isu Kabut Asap hingga In...
# 2     Viral! Driver Ojol di Bekasi Antar Pesanan Mak...
# 3     Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...
# 4     MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...
# ...                                                 ...
# 8608  Twice Rilis Teaser MV 'Feel Special' Jelang Co...
# 8609   Asap Karhutla Riau Mulai Merambah Ke Nias, BM...
# 8610  Tolak RUU Pertanahan, Ribuan Petani Siap Gelar...
# 8611  Ada Niat Tambah Momongan Tanpa Ikut Program Ha...
# 8612   TXT Akan Segera Comeback, Soobin Akui Gatal I...
#
#                                           cleaned_title
# 0     masuk radar pilwalkot medan menantu jokowi ber...
# 1     malaysia sudutkan ri isu kabut asap hingga inv...
# 2     viral driver ojol di bekasi antar pesanan maka...
# 3     kemensos salurkan rp 73 m bagi korban kerusuha...
# 4     mpr amandemen uud 1945 tak akan melebar ke man...
# ...                                                 ...
# 8608  twice rilis teaser mv 'feel special ' jelang c...
# 8609  asap karhutla riau mulai merambah ke nias bmkg...
# 8610  tolak ruu pertanahan ribuan petani siap gelar ...
# 8611  ada niat tambah momongan tanpa ikut program ha...
# 8612  txt akan segera comeback soobin akui gatal ing...
#
# [8613 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['title', 'label', 'label_score', 'comma_count', 'stop_count',
#        'question_count', 'exclamation_count', 'apostrophe_count',
#        'colon_count', 'semicolon_count', 'uppercase_count', 'lowercase_count',
#        'number_count', 'cleaned_title'],
#       dtype='object')

# %%
x = df.iloc[:,3:]
y = df.iloc[:,2]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=77)

# %%
print(x_train.shape)
print(y_test.shape)
# Out:
# (6890, 11)
# (1723,)

# %%
x_train_title = x_train['cleaned_title']
x_test_title = x_test['cleaned_title']

x_train_punc = x_train.drop('cleaned_title', axis=1)
x_test_punc = x_test.drop('cleaned_title', axis=1)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train_title)

x_train_title = tokenizer.texts_to_sequences(x_train_title)
x_test_title = tokenizer.texts_to_sequences(x_test_title)

# %%
tokenizer.word_index
# Out:
# {'di': 1,
#  'ini': 2,
#  'dan': 3,
#  'yang': 4,
#  "'": 5,
#  'ke': 6,
#  'jadi': 7,
#  'kpk': 8,
#  '2019': 9,
#  'indonesia': 10,
#  'tak': 11,
#  'untuk': 12,
#  'dengan': 13,
#  'habibie': 14,
#  'dari': 15,
#  'dpr': 16,
#  'polisi': 17,
#  'jokowi': 18,
#  'saat': 19,
#  'soal': 20,
#  'akan': 21,
#  'uu': 22,
#  'baru': 23,
#  'minta': 24,
#  'anak': 25,
#  'ada': 26,
#  'mahasiswa': 27,
#  'bisa': 28,
#  'hingga': 29,
#  'demo': 30,
#  'bikin': 31,
#  '3': 32,
#  'asap': 33,
#  'vs': 34,
#  'kota': 35,
#  'revisi': 36,
#  '5': 37,
#  'gara': 38,
#  'hari': 39,
#  'papua': 40,
#  'bj': 41,
#  '4': 42,
#  'tahun': 43,
#  '2': 44,
#  'usai': 45,
#  'liga': 46,
#  'sebut': 47,
#  'warga': 48,
#  'bakal': 49,
#  'orang': 50,
#  'rumah': 51,
#  'sinopsis': 52,
#  '1': 53,
#  'begini': 54,
#  'dalam': 55,
#  'dunia': 56,
#  'gelar': 57,
#  'kabut': 58,
#  'jakarta': 59,
#  'siap': 60,
#  'ibu': 61,
#  'rp': 62,
#  'karena': 63,
#  'foto': 64,
#  'jalan': 65,
#  'mobil': 66,
#  'sudah': 67,
#  'apa': 68,
#  'lebih': 69,
#  'dki': 70,
#  'pemerintah': 71,
#  'episode': 72,
#  '2020': 73,
#  'korban': 74,
#  'masih': 75,
#  'kasus': 76,
#  'air': 77,
#  'ingin': 78,
#  'karhutla': 79,
#  'tidak': 80,
#  'kembali': 81,
#  'aksi': 82,
#  'alasan': 83,
#  'pada': 84,
#  'viral': 85,
#  'beri': 86,
#  'naik': 87,
#  'anggota': 88,
#  'presiden': 89,
#  'pakai': 90,
#  'juta': 91,
#  'tewas': 92,
#  'lagi': 93,
#  'ruu': 94,
#  'cara': 95,
#  'dprd': 96,
#  'ungkap': 97,
#  'video': 98,
#  'fakta': 99,
#  'harga': 100,
#  'tayang': 101,
#  '6': 102,
#  'timnas': 103,
#  '10': 104,
#  'sinetron': 105,
#  'meninggal': 106,
#  'ikut': 107,
#  'menteri': 108,
#  'belum': 109,
#  'kata': 110,
#  'pertama': 111,
#  'hasil': 112,
#  'china': 113,
#  'tersangka': 114,
#  'tolak': 115,
#  'dua': 116,
#  'anies': 117,
#  '16': 118,
#  'bareng': 119,
#  '7': 120,
#  'film': 121,
#  'zodiak': 122,
#  'drama': 123,
#  'harus': 124,
#  'as': 125,
#  'dapat': 126,
#  'kebakaran': 127,
#  'jelang': 128,
#  'minyak': 129,
#  'suami': 130,
#  'ketua': 131,
#  'pria': 132,
#  'diri': 133,
#  'setelah': 134,
#  'saudi': 135,
#  'kesehatan': 136,
#  'masuk': 137,
#  'listrik': 138,
#  'genap': 139,
#  'punya': 140,
#  'pernah': 141,
#  'tol': 142,
#  'depan': 143,
#  'ganjil': 144,
#  'pemain': 145,
#  'pelajar': 146,
#  'turun': 147,
#  'bandara': 148,
#  'paling': 149,
#  'open': 150,
#  'bts': 151,
#  'pimpinan': 152,
#  'riau': 153,
#  'tni': 154,
#  'sempat': 155,
#  'diduga': 156,
#  'malaysia': 157,
#  'ternyata': 158,
#  'united': 159,
#  'fans': 160,
#  'lakukan': 161,
#  'hutan': 162,
#  'netizen': 163,
#  'disebut': 164,
#  'banyak': 165,
#  'mulai': 166,
#  '8': 167,
#  'terbakar': 168,
#  'massa': 169,
#  'cinta': 170,
#  'ri': 171,
#  'istri': 172,
#  '11': 173,
#  'jadwal': 174,
#  'u': 175,
#  'industri': 176,
#  'buka': 177,
#  'mantan': 178,
#  'bulan': 179,
#  'inggris': 180,
#  'tanpa': 181,
#  'siapa': 182,
#  'negara': 183,
#  'september': 184,
#  'kali': 185,
#  'gubernur': 186,
#  'lewat': 187,
#  'mau': 188,
#  'satu': 189,
#  'lee': 190,
#  'bersama': 191,
#  'malah': 192,
#  'tetap': 193,
#  'resmi': 194,
#  'akui': 195,
#  'masyarakat': 196,
#  'bukan': 197,
#  'miliar': 198,
#  'bagi': 199,
#  'bebby': 200,
#  'fey': 201,
#  'cerita': 202,
#  '9': 203,
#  'dukung': 204,
#  'pamer': 205,
#  'segera': 206,
#  'emas': 207,
#  'sekolah': 208,
#  'terima': 209,
#  'thailand': 210,
#  'jangan': 211,
#  'buat': 212,
#  'tampil': 213,
#  'sebagai': 214,
#  'besar': 215,
#  '0': 216,
#  'akhir': 217,
#  'cantik': 218,
#  'bank': 219,
#  'tiga': 220,
#  'barat': 221,
#  'bekasi': 222,
#  'april': 223,
#  'nama': 224,
#  'cukai': 225,
#  'atas': 226,
#  'hanya': 227,
#  'seperti': 228,
#  'ekonomi': 229,
#  'pekan': 230,
#  'piala': 231,
#  'lahan': 232,
#  'kecelakaan': 233,
#  'capim': 234,
#  'akibat': 235,
#  'sebelum': 236,
#  'bangun': 237,
#  'serangan': 238,
#  'keluarga': 239,
#  'bali': 240,
#  'sukses': 241,
#  'raih': 242,
#  'paris': 243,
#  'babak': 244,
#  'gempa': 245,
#  'hal': 246,
#  'dorong': 247,
#  'makin': 248,
#  'sama': 249,
#  'investasi': 250,
#  '15': 251,
#  'istana': 252,
#  'ahmad': 253,
#  'sang': 254,
#  'calon': 255,
#  'uang': 256,
#  'persen': 257,
#  'kerja': 258,
#  'perlu': 259,
#  'tim': 260,
#  'program': 261,
#  'wali': 262,
#  'tips': 263,
#  'luna': 264,
#  'bunga': 265,
#  'barbie': 266,
#  'beli': 267,
#  'triliun': 268,
#  'dewan': 269,
#  'tapi': 270,
#  'alami': 271,
#  'artis': 272,
#  'terus': 273,
#  'm': 274,
#  'muda': 275,
#  'kepala': 276,
#  'mati': 277,
#  'imam': 278,
#  'langsung': 279,
#  'polri': 280,
#  'agar': 281,
#  'iran': 282,
#  'pasar': 283,
#  'pesan': 284,
#  'ihsg': 285,
#  'rokok': 286,
#  'lagu': 287,
#  'pembangunan': 288,
#  'motor': 289,
#  'ratusan': 290,
#  'ajak': 291,
#  'festival': 292,
#  'veronica': 293,
#  'ditangkap': 294,
#  'hadapi': 295,
#  'ribu': 296,
#  'sering': 297,
#  'kirim': 298,
#  'sampai': 299,
#  'akhirnya': 300,
#  'siapkan': 301,
#  'nahrawi': 302,
#  'bpjs': 303,
#  'hukum': 304,
#  'rkuhp': 305,
#  'narkoba': 306,
#  'kuhp': 307,
#  'bertemu': 308,
#  'the': 309,
#  '17': 310,
#  'super': 311,
#  'mei': 312,
#  'pelatih': 313,
#  'diminta': 314,
#  'tuai': 315,
#  'malam': 316,
#  'bahas': 317,
#  'eks': 318,
#  'pb': 319,
#  'djarum': 320,
#  'kisah': 321,
#  'undang': 322,
#  'wanita': 323,
#  'per': 324,
#  'dinilai': 325,
#  'koman': 326,
#  'sri': 327,
#  'setuju': 328,
#  'perusahaan': 329,
#  'ribuan': 330,
#  'kivlan': 331,
#  'bandung': 332,
#  'mata': 333,
#  'live': 334,
#  'siswa': 335,
#  'kumalasari': 336,
#  'luar': 337,
#  'tangkap': 338,
#  'halilintar': 339,
#  'kamu': 340,
#  'tinggi': 341,
#  'atau': 342,
#  'tahu': 343,
#  'man': 344,
#  'lain': 345,
#  'alasannya': 346,
#  'jabar': 347,
#  'hamil': 348,
#  'kualifikasi': 349,
#  'sakit': 350,
#  'penyebab': 351,
#  "'cinta": 352,
#  'hati': 353,
#  'tentang': 354,
#  'kini': 355,
#  'bawa': 356,
#  'gagal': 357,
#  'jika': 358,
#  'lokasi': 359,
#  'medan': 360,
#  'rapat': 361,
#  'wisata': 362,
#  'balik': 363,
#  'atta': 364,
#  'polda': 365,
#  'korea': 366,
#  'putra': 367,
#  'madrid': 368,
#  'nasional': 369,
#  'jam': 370,
#  'kondisi': 371,
#  'terbaik': 372,
#  'gunung': 373,
#  'puluhan': 374,
#  'solo': 375,
#  'blackpink': 376,
#  'syahrini': 377,
#  'saja': 378,
#  'kedua': 379,
#  'pesawat': 380,
#  'champions': 381,
#  'liverpool': 382,
#  'lawan': 383,
#  'rusuh': 384,
#  'sidang': 385,
#  'atasi': 386,
#  'rupiah': 387,
#  'surabaya': 388,
#  'demi': 389,
#  'audisi': 390,
#  'seorang': 391,
#  'oktober': 392,
#  'bogor': 393,
#  'bantah': 394,
#  'trump': 395,
#  'korupsi': 396,
#  'zen': 397,
#  'nikita': 398,
#  'makan': 399,
#  'sampah': 400,
#  'penjelasan': 401,
#  'rilis': 402,
#  'dana': 403,
#  'komisi': 404,
#  'pbb': 405,
#  'komentar': 406,
#  'juara': 407,
#  'pemprov': 408,
#  'capai': 409,
#  'online': 410,
#  'ulang': 411,
#  'bayi': 412,
#  'perempuan': 413,
#  '20': 414,
#  'sorotan': 415,
#  'mengaku': 416,
#  'gerindra': 417,
#  'anggaran': 418,
#  'terakhir': 419,
#  'gandeng': 420,
#  'negeri': 421,
#  'pilih': 422,
#  'exo': 423,
#  'persib': 424,
#  'intip': 425,
#  'pdip': 426,
#  'tempat': 427,
#  'daftar': 428,
#  'reaksi': 429,
#  'penerbangan': 430,
#  'umum': 431,
#  'terkait': 432,
#  'pengesahan': 433,
#  'kamis': 434,
#  'hujan': 435,
#  'bantu': 436,
#  'udara': 437,
#  'mirzani': 438,
#  'gunakan': 439,
#  'bi': 440,
#  'suku': 441,
#  'itu': 442,
#  'mulyani': 443,
#  'pegawai': 444,
#  'eropa': 445,
#  'makassar': 446,
#  'masalah': 447,
#  'sendiri': 448,
#  'pastikan': 449,
#  'para': 450,
#  'janji': 451,
#  'australia': 452,
#  'tidur': 453,
#  'luncurkan': 454,
#  'bupati': 455,
#  'terjadi': 456,
#  'pengusaha': 457,
#  'mewah': 458,
#  'pernikahan': 459,
#  'ngaku': 460,
#  'wakil': 461,
#  'besok': 462,
#  'partai': 463,
#  'perluasan': 464,
#  'terungkap': 465,
#  'nilai': 466,
#  'trotoar': 467,
#  'sosok': 468,
#  'liburan': 469,
#  'lalu': 470,
#  'menpora': 471,
#  'terbaru': 472,
#  'bukti': 473,
#  'perang': 474,
#  'persija': 475,
#  'susi': 476,
#  'raffi': 477,
#  'seksi': 478,
#  'proyek': 479,
#  'politik': 480,
#  'batu': 481,
#  'tokoh': 482,
#  'saya': 483,
#  'hye': 484,
#  'hilang': 485,
#  'tetapkan': 486,
#  '30': 487,
#  'pln': 488,
#  'data': 489,
#  'heboh': 490,
#  'kembangkan': 491,
#  'izin': 492,
#  'fashion': 493,
#  'kilang': 494,
#  'suka': 495,
#  'tengah': 496,
#  'tanah': 497,
#  'oleh': 498,
#  'pelaku': 499,
#  'diprediksi': 500,
#  'top': 501,
#  'bayar': 502,
#  'ekspor': 503,
#  'prediksi': 504,
#  'pilkada': 505,
#  'ketiga': 506,
#  '19': 507,
#  'cegah': 508,
#  'gaya': 509,
#  'hidup': 510,
#  'digital': 511,
#  'juga': 512,
#  'pabrik': 513,
#  'pasca': 514,
#  'kemenhub': 515,
#  'pajak': 516,
#  'perdana': 517,
#  '100': 518,
#  'salah': 519,
#  'main': 520,
#  'kantor': 521,
#  'kena': 522,
#  'golkar': 523,
#  'kerusuhan': 524,
#  'se': 525,
#  'mana': 526,
#  'lengkap': 527,
#  'anaknya': 528,
#  'arsenal': 529,
#  'amerika': 530,
#  'penumpang': 531,
#  'streaming': 532,
#  'kim': 533,
#  'petugas': 534,
#  'kendaraan': 535,
#  'manfaat': 536,
#  'rambut': 537,
#  'mu': 538,
#  'bongkar': 539,
#  'rabu': 540,
#  'umumkan': 541,
#  'pasal': 542,
#  'coba': 543,
#  'wajah': 544,
#  'rekor': 545,
#  'panas': 546,
#  'hotman': 547,
#  'sumut': 548,
#  'impor': 549,
#  'gol': 550,
#  'bentuk': 551,
#  'kulit': 552,
#  'menarik': 553,
#  'bantuan': 554,
#  'api': 555,
#  'menang': 556,
#  'mandiri': 557,
#  'utang': 558,
#  'peserta': 559,
#  'putri': 560,
#  'tegaskan': 561,
#  'dampak': 562,
#  'ayam': 563,
#  'ancam': 564,
#  'tingkatkan': 565,
#  'desak': 566,
#  'fahri': 567,
#  'menguat': 568,
#  'pro': 569,
#  'ainun': 570,
#  'pengawas': 571,
#  'jambi': 572,
#  'pagi': 573,
#  'syuting': 574,
#  'aplikasi': 575,
#  'demokrat': 576,
#  'wagub': 577,
#  'bocah': 578,
#  'diamankan': 579,
#  'temukan': 580,
#  'asal': 581,
#  'pasangan': 582,
#  'pejabat': 583,
#  'hotel': 584,
#  'guru': 585,
#  'berikut': 586,
#  'jayapura': 587,
#  'daerah': 588,
#  'kaki': 589,
#  'google': 590,
#  'twice': 591,
#  'x': 592,
#  'status': 593,
#  'truk': 594,
#  'senin': 595,
#  'panggil': 596,
#  'kritik': 597,
#  'merasa': 598,
#  'red': 599,
#  'utara': 600,
#  'tangsel': 601,
#  'dewi': 602,
#  'city': 603,
#  'jenazah': 604,
#  'langit': 605,
#  'bagaimana': 606,
#  'desa': 607,
#  'luka': 608,
#  'tv': 609,
#  'bunuh': 610,
#  'iii': 611,
#  'arab': 612,
#  'bahan': 613,
#  'grup': 614,
#  'comeback': 615,
#  'ronaldo': 616,
#  'bea': 617,
#  'damai': 618,
#  'bmkg': 619,
#  'pemkot': 620,
#  'kpai': 621,
#  'berat': 622,
#  'tangan': 623,
#  'laga': 624,
#  'drone': 625,
#  'ala': 626,
#  'penghargaan': 627,
#  'ham': 628,
#  'jatim': 629,
#  'usia': 630,
#  'baik': 631,
#  'bicara': 632,
#  'bumn': 633,
#  'ii': 634,
#  'fc': 635,
#  'pak': 636,
#  'petani': 637,
#  'kabar': 638,
#  'ikuti': 639,
#  'iphone': 640,
#  'mirip': 641,
#  '23': 642,
#  'sun': 643,
#  'ditutup': 644,
#  'turunkan': 645,
#  'terhadap': 646,
#  'suara': 647,
#  'wamena': 648,
#  'dekat': 649,
#  'kalimantan': 650,
#  'sistem': 651,
#  'jk': 652,
#  'lihat': 653,
#  'panjang': 654,
#  'dinas': 655,
#  'jateng': 656,
#  'jalani': 657,
#  'produksi': 658,
#  '12': 659,
#  'wiranto': 660,
#  'bus': 661,
#  'medsos': 662,
#  'ilegal': 663,
#  'jalur': 664,
#  'hong': 665,
#  'kawasan': 666,
#  'pemkab': 667,
#  '18': 668,
#  'respons': 669,
#  'mundur': 670,
#  'masa': 671,
#  'cari': 672,
#  '50': 673,
#  'peluang': 674,
#  'idol': 675,
#  'baju': 676,
#  'ambon': 677,
#  'sejumlah': 678,
#  'minum': 679,
#  'sepeda': 680,
#  'baswedan': 681,
#  'ditemukan': 682,
#  'suci': 683,
#  'mereka': 684,
#  'ajukan': 685,
#  'dugaan': 686,
#  'still': 687,
#  'resep': 688,
#  'kami': 689,
#  'surat': 690,
#  'kalah': 691,
#  'cs': 692,
#  'perhatian': 693,
#  'investor': 694,
#  'penjualan': 695,
#  'meski': 696,
#  'temui': 697,
#  'asia': 698,
#  'kopi': 699,
#  'motogp': 700,
#  'protes': 701,
#  'week': 702,
#  'smp': 703,
#  'poin': 704,
#  'pertamina': 705,
#  'dianggap': 706,
#  'rasa': 707,
#  'sby': 708,
#  'meluncur': 709,
#  'maya': 710,
#  'dipuji': 711,
#  'menangis': 712,
#  'ridwan': 713,
#  'kamil': 714,
#  "'orang": 715,
#  'e': 716,
#  'ricuh': 717,
#  'emak': 718,
#  'barcelona': 719,
#  'serang': 720,
#  'jepang': 721,
#  'garuda': 722,
#  'pekat': 723,
#  'asing': 724,
#  'ngakak': 725,
#  'member': 726,
#  'terluka': 727,
#  'wilayah': 728,
#  'bola': 729,
#  'nct': 730,
#  'raditya': 731,
#  'i': 732,
#  'jefri': 733,
#  'nichol': 734,
#  'mpr': 735,
#  'gabung': 736,
#  'nggak': 737,
#  'muncul': 738,
#  'buta': 739,
#  'tanggapan': 740,
#  'sejak': 741,
#  'wajib': 742,
#  'shin': 743,
#  'aturan': 744,
#  'cina': 745,
#  'pelantikan': 746,
#  'honda': 747,
#  'show': 748,
#  'bpk': 749,
#  'ambil': 750,
#  'gedung': 751,
#  'kalau': 752,
#  'islam': 753,
#  'semakin': 754,
#  'cukup': 755,
#  'bak': 756,
#  '22': 757,
#  'level': 758,
#  'buruk': 759,
#  'sindir': 760,
#  'ramai': 761,
#  'k': 762,
#  'sumsel': 763,
#  'sepanjang': 764,
#  'kong': 765,
#  'singapura': 766,
#  'psg': 767,
#  'ikan': 768,
#  'semua': 769,
#  'debut': 770,
#  'nikah': 771,
#  'netter': 772,
#  'kocak': 773,
#  'hoaks': 774,
#  'antam': 775,
#  'iuran': 776,
#  'butuh': 777,
#  'kuat': 778,
#  'haji': 779,
#  'simak': 780,
#  'cepat': 781,
#  'atlet': 782,
#  'milan': 783,
#  'halal': 784,
#  'spanyol': 785,
#  'saham': 786,
#  'disahkan': 787,
#  'and': 788,
#  'dika': 789,
#  'operasi': 790,
#  'cek': 791,
#  'young': 792,
#  'ting': 793,
#  'hampir': 794,
#  'pemuda': 795,
#  'daniel': 796,
#  'kelas': 797,
#  'nagita': 798,
#  'ditunda': 799,
#  'era': 800,
#  'senjata': 801,
#  'bekas': 802,
#  'selama': 803,
#  'brimob': 804,
#  'beroperasi': 805,
#  'keren': 806,
#  'ingatkan': 807,
#  'serahkan': 808,
#  'selatan': 809,
#  'depok': 810,
#  'ambulans': 811,
#  'publik': 812,
#  'cuma': 813,
#  'selasa': 814,
#  'pesantren': 815,
#  'beredar': 816,
#  'bapak': 817,
#  'jawa': 818,
#  'jerman': 819,
#  'penuh': 820,
#  'pacar': 821,
#  'berhenti': 822,
#  'bagikan': 823,
#  'adik': 824,
#  'musim': 825,
#  'kualitas': 826,
#  'gigi': 827,
#  '40': 828,
#  'produk': 829,
#  'konser': 830,
#  'tsunami': 831,
#  'amankan': 832,
#  'pulang': 833,
#  'kepada': 834,
#  'inilah': 835,
#  'pakar': 836,
#  'pop': 837,
#  'semarang': 838,
#  'cetak': 839,
#  'postingan': 840,
#  'ditahan': 841,
#  'ganteng': 842,
#  'sangat': 843,
#  'masjid': 844,
#  'real': 845,
#  'waktu': 846,
#  'bela': 847,
#  'gratis': 848,
#  'makanan': 849,
#  'dibuka': 850,
#  'empat': 851,
#  'kementan': 852,
#  'berbahaya': 853,
#  'sriwijaya': 854,
#  'penampilan': 855,
#  'dikabarkan': 856,
#  'toyota': 857,
#  'terpilih': 858,
#  'asn': 859,
#  'skor': 860,
#  'gibran': 861,
#  'tua': 862,
#  'filipina': 863,
#  'evaluasi': 864,
#  'selain': 865,
#  'targetkan': 866,
#  'bulu': 867,
#  'velvet': 868,
#  'titik': 869,
#  'ganja': 870,
#  'fraksi': 871,
#  'rayakan': 872,
#  'mafia': 873,
#  'tawarkan': 874,
#  'tembak': 875,
#  'pengacara': 876,
#  'potret': 877,
#  'sehat': 878,
#  'marquez': 879,
#  'yuk': 880,
#  'aman': 881,
#  'jong': 882,
#  'selalu': 883,
#  '25': 884,
#  'bisnis': 885,
#  'mulan': 886,
#  'ditetapkan': 887,
#  'unggah': 888,
#  'telah': 889,
#  'siang': 890,
#  'pemindahan': 891,
#  'menhub': 892,
#  'pengendara': 893,
#  'kenaikan': 894,
#  'jumlah': 895,
#  'fokus': 896,
#  'posisi': 897,
#  'pertemuan': 898,
#  'penyakit': 899,
#  'dokter': 900,
#  'gading': 901,
#  'kita': 902,
#  'lima': 903,
#  'rusia': 904,
#  'bebas': 905,
#  'harap': 906,
#  'teroris': 907,
#  'jawaban': 908,
#  'apresiasi': 909,
#  'aramco': 910,
#  'diserang': 911,
#  'tanda': 912,
#  'tangerang': 913,
#  'aktivis': 914,
#  'ramalan': 915,
#  'berpotensi': 916,
#  'maut': 917,
#  'si': 918,
#  'media': 919,
#  'pariwisata': 920,
#  'banjir': 921,
#  'agung': 922,
#  'kalahkan': 923,
#  'cerai': 924,
#  'isu': 925,
#  'belajar': 926,
#  'wafat': 927,
#  'dukungan': 928,
#  'kekerasan': 929,
#  'dirut': 930,
#  'isyaratkan': 931,
#  'beda': 932,
#  'periksa': 933,
#  'terganggu': 934,
#  'penting': 935,
#  'panglima': 936,
#  'angkat': 937,
#  'siaran': 938,
#  'persipura': 939,
#  'jaga': 940,
#  'min': 941,
#  'paripurna': 942,
#  'cewek': 943,
#  'juventus': 944,
#  'rencana': 945,
#  'properti': 946,
#  'yakin': 947,
#  'pesta': 948,
#  'puji': 949,
#  'de': 950,
#  'target': 951,
#  'rahasia': 952,
#  'digelar': 953,
#  'laki': 954,
#  'lapor': 955,
#  'ganti': 956,
#  'benar': 957,
#  'tanggapi': 958,
#  'singgung': 959,
#  'reino': 960,
#  'alat': 961,
#  'proses': 962,
#  'group': 963,
#  'mampu': 964,
#  'terbitkan': 965,
#  'kapal': 966,
#  'tunggu': 967,
#  'tepat': 968,
#  'model': 969,
#  'uji': 970,
#  'manchester': 971,
#  'kemarau': 972,
#  'pupr': 973,
#  'jaya': 974,
#  'final': 975,
#  'aceh': 976,
#  'usaha': 977,
#  'unik': 978,
#  'bangsa': 979,
#  'kenapa': 980,
#  'internasional': 981,
#  'tuntut': 982,
#  'sulit': 983,
#  'posting': 984,
#  'hamzah': 985,
#  'gerakan': 986,
#  'beberkan': 987,
#  'jatuh': 988,
#  'ramah': 989,
#  'lingkungan': 990,
#  'milik': 991,
#  'tembus': 992,
#  'bumi': 993,
#  'daihatsu': 994,
#  'keuangan': 995,
#  'selamat': 996,
#  'tubuh': 997,
#  'asli': 998,
#  'bawah': 999,
#  'lintas': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)
vocab_size
# Out:
# 12509

# %%
lengths = []
for sentence in x_train_title:
    lengths.append(len(sentence))

print('Longest sentence\t:', max(lengths))
print('Shortest sentence\t:', min(lengths))
print('average length\t\t:', np.mean(lengths))
# Out:
# Longest sentence	: 19
# Shortest sentence	: 2
# average length		: 9.792162554426705

# %%
x_train_title = sequence.pad_sequences(x_train_title, maxlen=19)
x_test_title = sequence.pad_sequences(x_test_title, maxlen=19)

# %%
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1]),
    y=y_train.values
)
class_weights
# Out:
# array([0.80868545, 1.30988593])

# %%
class_weights_dict = dict(enumerate(class_weights))
class_weights_dict
# Out:
# {0: np.float64(0.8086854460093896), 1: np.float64(1.3098859315589353)}

# %%
print(x_train_title.shape)
print(x_test_title.shape)
# Out:
# (6890, 19)
# (1723, 19)

# %%
tf.random.set_seed(99)

lstm_input = Input(shape=(19,))
lstm = Embedding(input_dim=vocab_size+1, output_dim=32, input_length=19)(lstm_input)
lstm = LSTM(3)(lstm)
lstm = Dropout(rate=0.5)(lstm)
lstm = Dense(3, activation='sigmoid')(lstm)

lstm_modul = Model(inputs=lstm_input, outputs=lstm)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
dense_input = Input(shape=(10,))
dense = Dropout(rate=0.5)(dense_input)
dense = Dense(3, activation='sigmoid')(dense)
dense_model = Model(inputs=dense_input, outputs=dense)

# %%
print(x_train_punc.sample)
print(x_test_punc.shape)
# Out:
# <bound method NDFrame.sample of       comma_count  stop_count  question_count  exclamation_count  \
# 3877            2           0               0                  0
# 2861            1           0               0                  0
# 3871            1           0               0                  0
# 3256            0           0               0                  1
# 5415            1           0               0                  0
# ...           ...         ...             ...                ...
# 5237            0           0               0                  0
# 167             0           0               0                  0
# 4832            0           0               0                  0
# 7832            0           0               0                  0
# 2283            0           0               0                  0
#
#       apostrophe_count  colon_count  semicolon_count  uppercase_count  \
# 3877                 0            0                0               10
# 2861                 0            0                0                7
# 3871                 0            0                0                9
# 3256                 0            1                0                8
# 5415                 0            0                0               14
# ...                ...          ...              ...              ...
# 5237                 0            0                0               10
# 167                  0            0                0                8
# 4832                 0            0                0                7
# 7832                 0            0                0               10
# 2283                 0            0                0                8
#
#       lowercase_count  number_count
# 3877               51             0
# 2861               36             0
# 3871               43             0
# 3256               35             0
# 5415               49             0
# ...               ...           ...
# 5237               44             0
# 167                60             0
# 4832               42             0
# 7832               54             0
# 2283               40             0
#
# [6890 rows x 10 columns]>
# (1723, 10)

# %%
concat = concatenate([lstm_modul.output, dense_model.output])
concat = Dense(6, activation='sigmoid')(concat)
concat = Dense(1, activation='sigmoid')(concat)
model = Model(inputs=[lstm_modul.input, dense_model.input], outputs=concat)

# %%
plot_model(model)

# %%
model.compile(loss='binary_crossentropy',
optimizer='adam',
metrics=['acc'])

# %%
history = model.fit([x_train_title, x_train_punc], y_train,
epochs=4, batch_size=64,
class_weight=class_weights_dict, validation_data=([x_test_title, x_test_punc], y_test))
# Out:
# Epoch 1/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - acc: 0.6183 - loss: 0.7081 - val_acc: 0.6019 - val_loss: 0.6796
# Epoch 2/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.6920 - loss: 0.6820 - val_acc: 0.7876 - val_loss: 0.6740
# Epoch 3/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.7710 - loss: 0.6514 - val_acc: 0.8851 - val_loss: 0.6316
# Epoch 4/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.8118 - loss: 0.5973 - val_acc: 0.8804 - val_loss: 0.5673

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['acc', 'val_acc'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
